# %% [markdown]
# <User>
# ## problem
# 问题小区(cellid='cellA')无线接通率为20%，根据规则RRC连接建立请求次数[ATTCONNESTAB]大于100并且无线接通率[RADIO_SUCC_RATE]大于0并且无线接通[RADIO_SUCC_RATE]小于30%，触发派单阈值。
#
# ## tools
# 硬件告警排查工具
# 邻区配置合理性检查工具
# 信号干扰排查工具
# 容量高负荷排查工具
# 邻区配置工具
# 短评估工具
#
# ## background knowledge
# ATTCONNESTAB:330
# RADIO_SUCC_RATE:20%
# 邻区列表:["cell1","cell2","cell3"]
# 硬件告警:[]
# </User>
#
# <response>
# <think>
# 这个小区存在接通率指标过低的问题。影响接通率指标的原因很多，如果硬件有故障导致信道接入失败、容量利用率过高导致新用户反复尝试接入、深度覆盖不足导致边缘用户接入失败率高、外部或内部干扰过大导致用户信噪比过低无法接入，这一类问题的优化，一般遵循以下步骤：
# 1、先排查硬件告警。检查本小区以及共站同覆盖小区小区是否存在故障告警。如果存在告警，则先处理告警。
# 2、考虑邻区配置是否正确，是否存在邻区漏配或错配的情况。如果存在问题，则先修改邻区配置。
# 3、检查是否存在超远邻区或错误的邻区对，这可能影响接通率指标。
# 4、考虑问题小区是否存在干扰问题导致指标劣化。
# 5、分析问题小区是否存在容量高负荷问题。
# 以上按顺序执行，如果上一个步骤成功了，而且短评估是达标的，则任务停止；如果执行成功但短评估不达标，则按顺序往下执行。
# 如果一个步骤执行失败了，则按直接按顺序往下执行。
# 以上最多执行两轮，超过两轮直接停止任务。
#
# 根据上述方法论，结合给出的背景信息，我推断该小区首先不存在告警（硬件告警列表为空），下一步我需要通过邻区配置合理性检查工具来检查邻区配置是否合理。
# </think>
# ## action
# [邻区配置合理性检查工具(cgi=xxx)]
# </response>
#
# <User>
# ## problem
# 问题小区(cellid='cellA')无线接通率为20%，根据规则RRC连接建立请求次数[ATTCONNESTAB]大于100并且无线接通率[RADIO_SUCC_RATE]大于0并且无线接通[RADIO_SUCC_RATE]小于30%，触发派单阈值。
#
# ## tools
# 硬件告警排查工具
# 邻区配置合理性检查工具
# 信号干扰排查工具
# 容量高负荷排查工具
# 邻区配置工具
# 短评估工具
#
# ## background knowledge
# ATTCONNESTAB:330
# RADIO_SUCC_RATE:20%
# 邻区列表:["cell1","cell2","cell3"]
# 硬件告警:[]
# 邻区配置合理性检查结果:[ "add": ["cellA","cellB"] ]
# </User>
#
# <response>
# <think>
# 这个小区存在接通率指标过低的问题。这一类问题的优化，一般遵循以下步骤：
# 1、先排查硬件告警。检查本小区以及共站同覆盖小区小区是否存在故障告警。如果存在告警，则先处理告警。
# 2、考虑邻区配置是否正确，是否存在邻区漏配或错配的情况。如果存在问题，则先修改邻区配置。
# 3、检查是否存在超远邻区或错误的邻区对，这可能影响接通率指标。
# 4、考虑问题小区是否存在干扰问题导致指标劣化。
# 5、分析问题小区是否存在容量高负荷问题。
# 以上按顺序执行，如果上一个步骤成功了，而且短评估是达标的，则任务停止；如果执行成功但短评估不达标，则按顺序往下执行。
# 如果一个步骤执行失败了，则按直接按顺序往下执行。
# 以上最多执行两轮，超过两轮直接停止任务。
#
# 根据上述方法论，结合给出的背景信息，我推断该小区首先不存在告警（硬件告警列表为空），其次存在邻区缺失的问题。这个时候我需要调用邻区配置工具来解决这个问题。
# 我的解决方案是添加cellA和cellB之间的邻区关系
# 并同时调用短评估工具来检验这个方法是否能闭环解决问题。
# </think>
# ## action
# [邻区配置工具(cellA,cellB),短评估工具(cgi=cellA)]
# </response>
#
# <User>
# ## problem
# 问题小区(cellid='cellA')无线接通率为20%，根据规则RRC连接建立请求次数[ATTCONNESTAB]大于100并且无线接通率[RADIO_SUCC_RATE]大于0并且无线接通[RADIO_SUCC_RATE]小于30%，触发派单阈值。
#
# ## tools
# 硬件告警排查工具
# 邻区配置合理性检查工具
# 信号干扰排查工具
# 容量高负荷排查工具
# 邻区配置工具
# 短评估工具
#
# ## background knowledge
# ATTCONNESTAB:330
# RADIO_SUCC_RATE:20%
# 邻区列表:["cell1","cell2","cell3"]
# 硬件告警:[]
# 邻区配置合理性检查结果:[ "add": ["cellA","cellB"] ]
# 邻区配置结果:[ "success": ["cellA","cellB"] ]
# 短评估结果:[ "result": "达标" ]
# </User>
#
# <response>
# <think>
# 这个小区存在接通率指标过低的问题。这一类问题的优化，一般遵循以下步骤：
# 1、先排查硬件告警。检查本小区以及共站同覆盖小区小区是否存在故障告警。如果存在告警，则先处理告警。
# 2、考虑邻区配置是否正确，是否存在邻区漏配或错配的情况。如果存在问题，则先修改邻区配置。
# 3、检查是否存在超远邻区或错误的邻区对，这可能影响接通率指标。
# 4、考虑问题小区是否存在干扰问题导致指标劣化。
# 5、分析问题小区是否存在容量高负荷问题。
# 以上按顺序执行，如果上一个步骤成功了，而且短评估是达标的，则任务停止；如果执行成功但短评估不达标，则按顺序往下执行。
# 如果一个步骤执行失败了，则按直接按顺序往下执行。
# 以上最多执行两轮，超过两轮直接停止任务。
# 根据上述方法论，结合给出的背景信息，我推断该小区首先不存在告警（硬件告警列表为空），其次存在邻区缺失的问题。这个时候我需要调用邻区配置工具来解决这个问题。
# 我的解决方案是添加cellA和cellB之间的邻区关系
# 现在看来配置工具的执行是成功的，短评估结果是达标，问题闭环解决了。
# </think>
# ## action
# 问题已经解决了，可以关闭这个工单了。
# </response>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <prompt>
# ## problem
# 小区接通率为xx，不满足条件：接通率>90%
#
# ## background knowledge
#
# kpi1:xx
# kpi2:xx
# kpi3:xx
# warning:["a":"error","b":"too hot"]
# para1:["a":"error","b":"too hot"]
# para2:["a":"error","b":"too hot"]
# </prompt>
#
# <response>
# <think>
# 根据根因定位的结果，结合系统补充的小区信息，我给出的参数修改方案如下：
# plan1：xxx
# 这个参数修改，可以通过调用function3来实现
#
# </think>
# action:[function3]
# </response>
